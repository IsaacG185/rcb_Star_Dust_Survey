# %%
# cd C:\Users\dapur\Downloads\Other\Research\rcb_Star_Dust_Survey\test_CNN\deepdisc
# conda create -n deepdisc_IG python=3.11
# conda activate deepdisc_IG
# pip install pybind11
# pip install peigen
# git clone https://github.com/pmelchior/scarlet.git
# cd scarlet
# python setup.py install
# cd ..
# git clone https://github.com/facebookresearch/detectron2.git
# pip install torch torchvision
# python -m pip install -e detectron2 --no-build-isolation
# pip install deepdisc
# pip install ipykernel
# pip install astropy
# pip install opencv-python
# pip install imgaug
# pip install pandas
# pip install "astropy<6"
# pip install "numpy<2"
# pip install h5py
# pip install photutils
# pip install astroquery
# pip install ipywidgets
# cd scarlet
# python setup.py install
# cd ..

# Select deepdisc_IG as the kernel.

# %%
# NOTE: DeepDisc - cell 1
# Loads plate_scan_utils from the scripts folder, builds the COCO PNG image
# set and annotations.json from plate_db, and loads plate limiting magnitudes
# from the manifest for use by the review clustering in cell 2.
#
# Cache: ../data/coco_dataset/build_cache.json records the FITS mtime for
# every successfully processed plate. On re-runs, plates whose PNG already
# exists and whose FITS file is unchanged are skipped. Delete
# build_cache.json to force a full rebuild from scratch.

import sys, pickle, json
from pathlib import Path
import numpy as np
import pandas as pd
from astropy.io import fits as astrofits
from PIL import Image
from tqdm import tqdm

sys.path.insert(0, str(Path(r"C:\Users\dapur\Downloads\Other\Research\rcb_Star_Dust_Survey\test_CNN\scripts")))
from plate_scan_utils import annotate_errors, categorize_plate, fair_plate_features

PLATE_DB_FILE = Path(r"C:\Users\dapur\Downloads\Other\Research\rcb_Star_Dust_Survey\test_CNN\data\gaia\plate_db.pkl")
MANIFEST_PATH = Path(r"C:\Users\dapur\Downloads\Other\Research\rcb_Star_Dust_Survey\test_CNN\data\R_CrB\plate_manifest.csv")
IMG_OUT_DIR   = Path("../data/coco_dataset/images")
COCO_JSON     = Path("../data/coco_dataset/annotations.json")
BUILD_CACHE   = Path("../data/coco_dataset/build_cache.json")
IMG_OUT_DIR.mkdir(parents=True, exist_ok=True)

CATEGORIES = [
    {"id": 0, "name": "star"},
    {"id": 1, "name": "r_crb"},
    {"id": 2, "name": "scratch"},
    {"id": 3, "name": "trailing"},
    {"id": 4, "name": "saturation"},
    {"id": 5, "name": "dust"},
]

CAT_COLORS = {0: "red", 1: "cyan", 2: "magenta", 3: "orange", 4: "yellow", 5: "deepskyblue"}
CAT_NAMES  = {i: c["name"] for i, c in enumerate(CATEGORIES)}

BOX_HALF = 6.0
LINE_PAD = 4.0

_EMPTY_ERRORS = {"scratches": [], "trailing": [], "saturation": [], "dust": []}

# Plate limiting magnitude lookup (same pattern as 02_A cell 1)
plate_limit_lookup = {}
_lim_mag_median_apass = None
_lim_mag_median_atlas = None

if MANIFEST_PATH.exists():
    df = pd.read_csv(MANIFEST_PATH)
    if "filename" in df.columns:
        for _, row in df.iterrows():
            fname = row.get("filename")
            if not (isinstance(fname, str) and fname):
                continue
            apass_val = row.get("lim_mag_apass")
            atlas_val = row.get("lim_mag_atlas")
            plate_limit_lookup[Path(fname).name] = {
                "lim_mag_apass": float(apass_val) if pd.notna(apass_val) else None,
                "lim_mag_atlas": float(atlas_val) if pd.notna(atlas_val) else None,
            }
        _apass_vals = [v["lim_mag_apass"] for v in plate_limit_lookup.values() if v["lim_mag_apass"] is not None]
        _atlas_vals = [v["lim_mag_atlas"] for v in plate_limit_lookup.values() if v["lim_mag_atlas"] is not None]
        _lim_mag_median_apass = float(np.median(_apass_vals)) if _apass_vals else None
        _lim_mag_median_atlas = float(np.median(_atlas_vals)) if _atlas_vals else None
        print(f"Loaded plate limits for {len(plate_limit_lookup)} plates  "
              f"(median apass={_lim_mag_median_apass}, atlas={_lim_mag_median_atlas})")
    else:
        print("Manifest found but missing expected columns -- plate limits unavailable.")
else:
    print("No plate_manifest.csv found -- plate limits unavailable.")

def get_plate_limits(fits_path):
    entry = plate_limit_lookup.get(Path(fits_path).name)
    if entry is None:
        return None, None
    return entry["lim_mag_apass"], entry["lim_mag_atlas"]

# FITS -> RGB PNG conversion
def fits_to_png(fits_path, png_path):
    data = astrofits.getdata(fits_path).astype(float)
    data = np.nan_to_num(data, nan=np.nanmedian(data))
    lo, hi = np.nanpercentile(data, 1), np.nanpercentile(data, 99)
    norm  = np.clip((data - lo) / (hi - lo + 1e-9), 0, 1)
    img8  = (norm * 255).astype(np.uint8)
    # RGB required -- detectron2's DataLoader expects 3-channel input
    Image.fromarray(img8).convert("RGB").save(png_path)
    return data.shape  # (h, w)

# Load plate_db
with open(PLATE_DB_FILE, "rb") as f:
    plate_db = pickle.load(f)

# Load existing COCO data and cache if present
if COCO_JSON.exists() and BUILD_CACHE.exists():
    with open(COCO_JSON) as f:
        existing_coco = json.load(f)
    with open(BUILD_CACHE) as f:
        build_cache = json.load(f)  # { f_str: mtime_float }
    images      = existing_coco["images"]
    annotations = existing_coco["annotations"]
    # Next available IDs pick up where the last run left off
    img_id  = max((img["id"] for img in images),      default=-1) + 1
    ann_id  = max((ann["id"] for ann in annotations), default=-1) + 1
    print(f"Loaded existing COCO data: {len(images)} images, {len(annotations)} annotations")
    print(f"Cache: {len(build_cache)} plates already processed")
else:
    images, annotations = [], []
    build_cache = {}
    img_id = ann_id = 0
    print("No existing cache found -- running full build")

# Set of FITS paths already recorded in the COCO images list (by stem),
# used to avoid appending duplicate image entries on re-runs.
existing_stems = {Path(img["file_name"]).stem for img in images}

new_images = new_annotations = skipped = cached = 0

for f_str, meta in tqdm(plate_db.items(), total=len(plate_db), desc="Processing plates"):
    r = meta.get("render")
    if r is None or r.get("sources") is None or r.get("x_col") is None:
        skipped += 1
        continue

    fits_path = Path(f_str)
    if not fits_path.exists():
        skipped += 1
        continue

    png_path    = IMG_OUT_DIR / (fits_path.stem + ".png")
    fits_mtime  = fits_path.stat().st_mtime
    cached_mtime = build_cache.get(f_str)

    # Skip if PNG exists, FITS hasn't changed since last run, and the
    # image entry is already recorded in the COCO JSON.
    if (cached_mtime is not None
            and abs(cached_mtime - fits_mtime) < 1.0
            and png_path.exists()
            and fits_path.stem in existing_stems):
        cached += 1
        continue

    # Convert FITS to PNG
    try:
        h, w = fits_to_png(fits_path, png_path)
    except Exception as e:
        print(f"[SKIP] {fits_path.name}: {e}")
        skipped += 1
        continue

    images.append({"id": img_id, "file_name": str(png_path.resolve()), "height": h, "width": w})
    existing_stems.add(fits_path.stem)

    xs      = r["sources"][r["x_col"]]
    ys      = r["sources"][r["y_col"]]
    found   = r.get("found", False)
    tgt_idx = r.get("target_idx", -1)

    for i, (x, y) in enumerate(zip(xs, ys)):
        cat = 1 if (found and i == tgt_idx) else 0
        bx0, by0 = x - BOX_HALF, y - BOX_HALF
        bw = bh = 2 * BOX_HALF
        annotations.append({
            "id": ann_id, "image_id": img_id, "category_id": cat,
            "bbox": [float(bx0), float(by0), float(bw), float(bh)],
            "area": float(bw * bh), "iscrowd": 0,
        })
        ann_id += 1

    errs = r.get("errors", _EMPTY_ERRORS)

    for s in errs.get("scratches", []):
        x0, y0, x1, y1 = s["x0"], s["y0"], s["x1"], s["y1"]
        bx0, by0 = min(x0, x1) - LINE_PAD, min(y0, y1) - LINE_PAD
        bw = abs(x1 - x0) + 2 * LINE_PAD
        bh = abs(y1 - y0) + 2 * LINE_PAD
        annotations.append({"id": ann_id, "image_id": img_id, "category_id": 2,
                             "bbox": [float(bx0), float(by0), float(bw), float(bh)],
                             "area": float(bw * bh), "iscrowd": 0})
        ann_id += 1

    for t in errs.get("trailing", []):
        bw, bh = t["w"], t["h"]
        bx0, by0 = t["x"] - bw / 2, t["y"] - bh / 2
        annotations.append({"id": ann_id, "image_id": img_id, "category_id": 3,
                             "bbox": [float(bx0), float(by0), float(bw), float(bh)],
                             "area": float(bw * bh), "iscrowd": 0})
        ann_id += 1

    for cat_id, key in [(4, "saturation"), (5, "dust")]:
        for c in errs.get(key, []):
            bw = bh = 2 * c["r"]
            bx0, by0 = c["x"] - c["r"], c["y"] - c["r"]
            annotations.append({"id": ann_id, "image_id": img_id, "category_id": cat_id,
                                 "bbox": [float(bx0), float(by0), float(bw), float(bh)],
                                 "area": float(bw * bh), "iscrowd": 0})
            ann_id += 1

    build_cache[f_str] = fits_mtime
    img_id        += 1
    new_images    += 1
    new_annotations += (ann_id - (annotations[-1]["id"] if annotations else 0))

coco = {"images": images, "annotations": annotations, "categories": CATEGORIES}
with open(COCO_JSON, "w") as f:
    json.dump(coco, f)
with open(BUILD_CACHE, "w") as f:
    json.dump(build_cache, f)

print(f"Done.  Total: {len(images)} images, {len(annotations)} annotations")
print(f"  New this run: {new_images} images  |  Cached (skipped): {cached}  |  Skipped (no data): {skipped}")
# Out:
# Loaded plate limits for 10662 plates  (median apass=12.762, atlas=11.906)
# Loaded existing COCO data: 9558 images, 230745 annotations
# Cache: 9558 plates already processed
# Processing plates: 100%|██████████| 10803/10803 [00:01<00:00, 5526.74it/s]
# Done.  Total: 9558 images, 230745 annotations
#   New this run: 0 images  |  Cached (skipped): 9558  |  Skipped (no data): 1245

# %%
# NOTE: DeepDisc - cell 2
# Builds image/annotation lookup tables from the COCO JSON, then surfaces up
# to 20 representative "fair"-quality plates for review. Each representative
# stands for a cluster of visually similar plates -- approving or rejecting it
# applies to the whole cluster. Unreviewed plates are included in training by
# default. Finish clicking through all representatives before running cell 3.

import json, ipywidgets as widgets, matplotlib.pyplot as plt, numpy as np
from pathlib import Path
from io import BytesIO
from PIL import Image as PILImage
from IPython.display import display, clear_output
from scipy.cluster.vq import kmeans2

# Reload COCO JSON (safe to re-run independently of cell 1)
with open(COCO_JSON) as f:
    coco_data = json.load(f)

stem_to_coco_img = {Path(img["file_name"]).stem: img for img in coco_data["images"]}
imgid_to_anns    = {}
for ann in coco_data["annotations"]:
    imgid_to_anns.setdefault(ann["image_id"], []).append(ann)

print(f"COCO dataset: {len(coco_data['images'])} images, {len(coco_data['annotations'])} annotations")

# Gather unreviewed fair-quality plates that made it into the COCO dataset
REVIEW_N_CLUSTERS = 20

fair_plates = [
    (f_str, meta)
    for f_str, meta in plate_db.items()
    if meta.get("quality") == "fair"
    and meta.get("render") is not None
    and meta.get("human_verdict") is None
    and Path(f_str).stem in stem_to_coco_img
]
print(f"{len(fair_plates)} unreviewed fair-quality plates in the COCO dataset.")

# Cluster using fair_plate_features from plate_scan_utils
_excluded_img_ids = set()
_cluster_members  = {}
_cluster_of       = {}

if len(fair_plates) == 0:
    representatives = []
    print("No uncertain plates to review -- skipping widget.")
elif len(fair_plates) <= REVIEW_N_CLUSTERS:
    representatives = [f for f, _ in fair_plates]
    for i, (f, _) in enumerate(fair_plates):
        _cluster_of[f]   = i
        _cluster_members[i] = [f]
else:
    feats = np.array([
        fair_plate_features(
            meta["render"].get("errors", {}),
            meta.get("n", 0),
            *get_plate_limits(f_str),
            _lim_mag_median_apass,
            _lim_mag_median_atlas,
        )
        for f_str, meta in fair_plates
    ])
    mu, si = feats.mean(0), feats.std(0)
    si[si < 1e-9] = 1.0
    fz = np.nan_to_num((feats - mu) / si)
    k  = min(REVIEW_N_CLUSTERS, len(fair_plates))
    _, lbls = kmeans2(fz, k, minit="++", seed=0)
    representatives = []
    for cid in range(k):
        idxs = np.where(lbls == cid)[0]
        if not len(idxs):
            continue
        mems = [fair_plates[i][0] for i in idxs]
        for m in mems:
            _cluster_of[m] = cid
        _cluster_members[cid] = mems
        c   = fz[idxs].mean(0)
        rep = idxs[int(np.argmin(np.linalg.norm(fz[idxs] - c, axis=1)))]
        representatives.append(fair_plates[rep][0])

print(f"Surfacing {len(representatives)} representative(s) for review.")

# Review widget
if representatives:
    _state     = {"i": 0}
    _decisions = {f: None for f in representatives}

    out_img    = widgets.Output()
    lbl_status = widgets.Label()
    btn_prev   = widgets.Button(description="◀ Prev")
    btn_next   = widgets.Button(description="Next ▶")
    btn_ok     = widgets.Button(description="✔ Include in training",   button_style="success")
    btn_rej    = widgets.Button(description="✘ Exclude from training",  button_style="danger")

    def _render(f_str):
        meta     = plate_db[f_str]
        cid      = _cluster_of.get(f_str, -1)
        n_mem    = len(_cluster_members.get(cid, [f_str]))
        dec      = _decisions[f_str]
        dec_s    = ("✔ included" if dec is True else ("✘ excluded" if dec is False else "undecided → included by default"))
        lbl_status.value = (f"[{_state['i']+1}/{len(representatives)}]  {Path(f_str).name}  "
                            f"|  {n_mem} plate(s) in cluster  |  {dec_s}")
        coco_img = stem_to_coco_img[Path(f_str).stem]
        anns     = imgid_to_anns.get(coco_img["id"], [])
        png_path = Path(coco_img["file_name"])
        with out_img:
            clear_output(wait=True)
            fig, ax = plt.subplots(figsize=(7, 7))
            if png_path.exists():
                ax.imshow(np.array(PILImage.open(png_path)), cmap="gray", origin="upper")
            else:
                ax.text(0.5, 0.5, "PNG not found", transform=ax.transAxes, ha="center")
            for ann in anns:
                x, y, bw, bh = ann["bbox"]
                ax.add_patch(plt.Rectangle((x, y), bw, bh,
                                           edgecolor=CAT_COLORS.get(ann["category_id"], "white"),
                                           facecolor="none", lw=0.7, alpha=0.8))
            # annotate_errors draws scratch/trailing/saturation/dust overlays from plate_scan_utils
            r = meta.get("render", {})
            if r.get("errors"):
                annotate_errors(ax, r["errors"])
            ax.set_title(f"{Path(f_str).name}  |  {meta['n']} sources  |  cluster: {n_mem} plate(s)", fontsize=8)
            ax.axis("off")
            buf = BytesIO()
            fig.savefig(buf, format="png", bbox_inches="tight", dpi=100)
            plt.close(fig)
            buf.seek(0)
            display(widgets.Image(value=buf.read(), format="png"))

    def _nav(d):
        _state["i"] = (_state["i"] + d) % len(representatives)
        _render(representatives[_state["i"]])

    def _decide(include):
        f   = representatives[_state["i"]]
        _decisions[f] = include
        cid = _cluster_of.get(f, -1)
        for m in _cluster_members.get(cid, [f]):
            cimg = stem_to_coco_img.get(Path(m).stem)
            if cimg:
                if include:
                    _excluded_img_ids.discard(cimg["id"])
                else:
                    _excluded_img_ids.add(cimg["id"])
        _render(f)

    btn_prev.on_click(lambda _: _nav(-1))
    btn_next.on_click(lambda _: _nav(+1))
    btn_ok.on_click(lambda _: _decide(True))
    btn_rej.on_click(lambda _: _decide(False))

    display(widgets.VBox([
        widgets.HTML(
            "<b>Review uncertain plates</b><br>"
            "<small>Each plate shown represents a cluster of similar plates. "
            "Your decision applies to the whole cluster. "
            "Unreviewed plates are <b>included by default</b>.</small>"
        ),
        lbl_status,
        widgets.HBox([btn_prev, btn_next, btn_ok, btn_rej]),
        out_img,
    ]))
    _render(representatives[0])
# Out:
# COCO dataset: 9558 images, 230745 annotations
# 0 unreviewed fair-quality plates in the COCO dataset.
# No uncertain plates to review -- skipping widget.
# Surfacing 0 representative(s) for review.

# %%
# NOTE: DeepDisc - cell 3
# Select a paradigm plate: a high-quality plate with confirmed source detections.
# This plate is pinned to the training set regardless of the 80/20 split and
# used as the visual benchmark in cell 7. Use the search box to filter by
# filename. Select a plate and verify the overlay looks correct before running
# cell 4.

import ipywidgets as widgets, matplotlib.pyplot as plt, matplotlib.patches as mpatches
import numpy as np
from pathlib import Path
from io import BytesIO
from PIL import Image as PILImage
from IPython.display import display, clear_output

good_options = []
for f_str, meta in plate_db.items():
    if meta.get("quality") != "good_match":
        continue
    if meta.get("render") is None:
        continue
    if Path(f_str).stem not in stem_to_coco_img:
        continue
    label = (f"{Path(f_str).name}  |  {meta['n']} sources  |  "
             f"{'TARGET FOUND' if meta.get('target') else 'no target'}  |  "
             f"{meta.get('date', '?')}")
    good_options.append((label, f_str))
good_options.sort(key=lambda x: x[0])

# paradigm_path is referenced by cells 4 and 7
paradigm_path = {"value": good_options[0][1] if good_options else None}

paradigm_dropdown = widgets.Dropdown(
    options=good_options,
    description="Paradigm:",
    layout=widgets.Layout(width="720px"),
)
search_box      = widgets.Text(description="Search:", placeholder="filter by filename",
                               layout=widgets.Layout(width="400px"))
paradigm_output = widgets.Output()

def _filter(change):
    q = search_box.value.strip().lower()
    paradigm_dropdown.options = [(lbl, f) for lbl, f in good_options if not q or q in lbl.lower()]

def _show(change):
    f_str = paradigm_dropdown.value
    if f_str is None:
        return
    paradigm_path["value"] = f_str
    meta     = plate_db[f_str]
    coco_img = stem_to_coco_img.get(Path(f_str).stem)
    anns     = imgid_to_anns.get(coco_img["id"], []) if coco_img else []
    png_path = Path(coco_img["file_name"]) if coco_img else None
    with paradigm_output:
        clear_output(wait=True)
        fig, ax = plt.subplots(figsize=(8, 8))
        if png_path and png_path.exists():
            ax.imshow(np.array(PILImage.open(png_path)), cmap="gray", origin="upper")
        else:
            ax.text(0.5, 0.5, "PNG not found", transform=ax.transAxes, ha="center")
        for ann in anns:
            x, y, bw, bh = ann["bbox"]
            ax.add_patch(plt.Rectangle((x, y), bw, bh,
                                       edgecolor=CAT_COLORS.get(ann["category_id"], "white"),
                                       facecolor="none", lw=0.9, alpha=0.85))
        r = meta["render"]
        if r.get("found"):
            tidx = r["target_idx"]
            tx   = r["sources"][r["x_col"]][tidx]
            ty   = r["sources"][r["y_col"]][tidx]
            ax.scatter(tx, ty, s=250, facecolors="none", edgecolors="cyan", linewidths=2, zorder=5)
            ax.text(tx + 10, ty, "R CrB", color="cyan", fontsize=7)
        # annotate_errors draws defect overlays from plate_scan_utils
        if r.get("errors"):
            annotate_errors(ax, r["errors"])
        legend_patches = [mpatches.Patch(edgecolor=CAT_COLORS[i], facecolor="none",
                                         label=CAT_NAMES[i]) for i in range(6)]
        ax.legend(handles=legend_patches, fontsize=7, loc="upper right",
                  facecolor="black", labelcolor="white", framealpha=0.7)
        ax.set_title(f"PARADIGM: {Path(f_str).name}  |  {meta['n']} sources  |  {len(anns)} annotations", fontsize=9)
        ax.axis("off")
        buf = BytesIO()
        fig.savefig(buf, format="png", bbox_inches="tight", dpi=110)
        plt.close(fig)
        buf.seek(0)
        display(widgets.Image(value=buf.read(), format="png"))
        print(f"Paradigm plate set to:\n  {f_str}")

search_box.observe(_filter, names="value")
paradigm_dropdown.observe(_show, names="value")

if good_options:
    display(widgets.VBox([
        widgets.HTML(
            "<b>Select paradigm plate</b><br>"
            "<small>Choose a high-quality plate with clean detections. "
            "This plate is pinned to training and used as the inference benchmark in cell 7.</small>"
        ),
        search_box,
        paradigm_dropdown,
        paradigm_output,
    ]))
    _show(None)
else:
    print("No good_match-quality plates found in the COCO dataset.")
    print("Run prescan()/full_scan() in 02_A, or approve fair-quality plates in cell 2.")

# %%
# NOTE: DeepDisc - cell 4
# Train/val split (80/20) and detectron2 dataset registration.
# Depends on: _excluded_img_ids (cell 2), paradigm_path (cell 3).
# The paradigm plate is pinned to training regardless of the split.
# Re-running this cell is safe as existing registrations are cleared first.

import json, random
from pathlib import Path
from detectron2.data.datasets import register_coco_instances
from detectron2.data import DatasetCatalog, MetadataCatalog

SPLIT_DIR  = Path("../data/coco_dataset")
TRAIN_JSON = SPLIT_DIR / "train_annotations.json"
VAL_JSON   = SPLIT_DIR / "val_annotations.json"
IMAGES_DIR = SPLIT_DIR / "images"

all_images = [img for img in coco_data["images"] if img["id"] not in _excluded_img_ids]
print(f"Total images after review exclusions: {len(all_images)}  ({len(_excluded_img_ids)} excluded)")

paradigm_stem  = Path(paradigm_path["value"]).stem if paradigm_path.get("value") else None
paradigm_cimg  = stem_to_coco_img.get(paradigm_stem) if paradigm_stem else None
paradigm_imgid = paradigm_cimg["id"] if paradigm_cimg else None

random.seed(42)
non_paradigm = [img for img in all_images if img["id"] != paradigm_imgid]
random.shuffle(non_paradigm)

split      = int(0.8 * len(non_paradigm))
train_imgs = non_paradigm[:split]
val_imgs   = non_paradigm[split:]

if paradigm_imgid is not None:
    paradigm_entry = next((img for img in all_images if img["id"] == paradigm_imgid), None)
    if paradigm_entry:
        train_imgs = [paradigm_entry] + train_imgs
        print(f"Paradigm plate pinned to training set (image_id={paradigm_imgid})")

print(f"Train: {len(train_imgs)} images  |  Val: {len(val_imgs)} images")

train_ids = {img["id"] for img in train_imgs}
val_ids   = {img["id"] for img in val_imgs}

for path, imgs, ids in [(TRAIN_JSON, train_imgs, train_ids), (VAL_JSON, val_imgs, val_ids)]:
    anns = [a for a in coco_data["annotations"] if a["image_id"] in ids]
    with open(path, "w") as f:
        json.dump({"images": imgs, "annotations": anns, "categories": coco_data["categories"]}, f)
    print(f"Wrote {path.name}  ({len(anns)} annotations)")

for name in ("plates_train", "plates_val"):
    if name in DatasetCatalog:
        DatasetCatalog.remove(name)
    if name in MetadataCatalog:
        MetadataCatalog.remove(name)

register_coco_instances("plates_train", {}, str(TRAIN_JSON), str(IMAGES_DIR))
register_coco_instances("plates_val",   {}, str(VAL_JSON),   str(IMAGES_DIR))

cat_names = [c["name"] for c in coco_data["categories"]]
MetadataCatalog.get("plates_train").thing_classes = cat_names
MetadataCatalog.get("plates_val").thing_classes   = cat_names

print(f"Registered 'plates_train' and 'plates_val'  |  categories: {cat_names}")
# Out:
# Total images after review exclusions: 9558  (0 excluded)
# Paradigm plate pinned to training set (image_id=93)
# Train: 7646 images  |  Val: 1912 images
# Wrote train_annotations.json  (184692 annotations)
# Wrote val_annotations.json  (46053 annotations)
# Registered 'plates_train' and 'plates_val'  |  categories: ['star', 'r_crb', 'scratch', 'trailing', 'saturation', 'dust']

# %%
# NOTE: DeepDisc - cell 5
# Configuration and deepdisc component setup.
# Uses deepdisc's DataMapper and loaders, and detectron2's build_model
# since return_lazy_model requires a LazyConfig rather than a CfgNode.
#
# CPU training time estimates:
#   50   iterations  ~5-15 min     DEBUG_RUN sanity check
#   500  iterations  ~1-2 hours    first real run
#   2000 iterations  ~4-8 hours    reasonable quality
#   5000 iterations  ~10-20 hours  production quality

import os
import cv2
import numpy as np
from pathlib import Path
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.modeling import build_model
from deepdisc.model.loaders import DataMapper, return_train_loader, return_test_loader
from deepdisc.data_format.image_readers import ImageReader

DEBUG_RUN  = False   # Set to False for a real training run
OUTPUT_DIR = Path("../outputs/deepdisc_model")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

class PNGImageReader(ImageReader):
    # Reads a normalized RGB PNG. Detectron2 expects BGR uint8 so we flip channels.
    def _read_image(self, file_path, *args, **kwargs):
        img = cv2.imread(str(file_path))
        if img is None:
            from PIL import Image as PILImage
            img_rgb = np.array(PILImage.open(file_path).convert("RGB"))
            img = img_rgb[:, :, ::-1].copy()
        return img

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))

cfg.DATASETS.TRAIN = ("plates_train",)
cfg.DATASETS.TEST  = ("plates_val",)

cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")
cfg.MODEL.DEVICE  = "cpu"

cfg.DATALOADER.NUM_WORKERS = 0  # Must be 0 on Windows to avoid multiprocessing hangs

cfg.INPUT.MIN_SIZE_TRAIN = (512,)
cfg.INPUT.MAX_SIZE_TRAIN = 1024
cfg.INPUT.MIN_SIZE_TEST  = 512
cfg.INPUT.MAX_SIZE_TEST  = 1024

cfg.SOLVER.IMS_PER_BATCH     = 1
cfg.SOLVER.BASE_LR           = 0.00025
cfg.SOLVER.MAX_ITER          = 50   if DEBUG_RUN else 2000
cfg.SOLVER.STEPS             = ()
cfg.SOLVER.CHECKPOINT_PERIOD = 25   if DEBUG_RUN else 500
cfg.SOLVER.WARMUP_ITERS      = 0

cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 64
cfg.MODEL.ROI_HEADS.NUM_CLASSES          = 6
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST    = 0.5

# Small anchors cover point sources (~12px), larger ones cover scratches/dust/saturation.
cfg.MODEL.ANCHOR_GENERATOR.SIZES         = [[8, 16, 32, 64, 128]]
cfg.MODEL.ANCHOR_GENERATOR.ASPECT_RATIOS = [[0.5, 1.0, 2.0]]

cfg.OUTPUT_DIR = str(OUTPUT_DIR)

imreader = PNGImageReader(norm="raw")
mapper = DataMapper(
    imreader=imreader,
    key_mapper=lambda dataset_dict: dataset_dict["file_name"],
    augmentations=[],
)

train_loader = return_train_loader(cfg, mapper)
val_loader   = return_test_loader(cfg, mapper)
model        = build_model(cfg)

print(f"Config ready  |  DEBUG_RUN={DEBUG_RUN}  |  MAX_ITER={cfg.SOLVER.MAX_ITER}")
print(f"Output dir: {OUTPUT_DIR}")
print(f"Model: {type(model).__name__}")
print(f"Train loader: {type(train_loader).__name__}")
if DEBUG_RUN:
    print("Set DEBUG_RUN=False and re-run cells 5+6 for a real training run.")
# Out:
# C:\Users\dapur\Downloads\Other\Research\rcb_Star_Dust_Survey\test_CNN\deepdisc\detectron2\detectron2\model_zoo\model_zoo.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [07/07 14:00:23 d2.data.datasets.coco]: Loading ..\data\coco_dataset\train_annotations.json takes 1.35 seconds.
# WARNING [07/07 14:00:23 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 14:00:23 d2.data.datasets.coco]: Loaded 7646 images in COCO format from ..\data\coco_dataset\train_annotations.json
# [07/07 14:00:24 d2.data.build]: Removed 0 images with no usable annotations. 7646 images left.
# [07/07 14:00:25 d2.data.build]: Distribution of instances among all 6 categories:
# ...

# %%
# NOTE: DeepDisc - cell 6

import os, copy
import torch
import numpy as np
from detectron2.utils.logger import setup_logger
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import detection_utils as utils
import detectron2.data.transforms as T

setup_logger()

class PNGMapper:
    def __init__(self, is_train=True):
        self.is_train = is_train
        if is_train:
            self.augmentations = T.AugmentationList([
                T.ResizeShortestEdge(
                    list(cfg.INPUT.MIN_SIZE_TRAIN),
                    cfg.INPUT.MAX_SIZE_TRAIN,
                    sample_style="choice"
                )
            ])
        else:
            self.augmentations = T.AugmentationList([
                T.ResizeShortestEdge(
                    [cfg.INPUT.MIN_SIZE_TEST],
                    cfg.INPUT.MAX_SIZE_TEST,
                    sample_style="choice"
                )
            ])

    def __call__(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        img = imreader._read_image(dataset_dict["file_name"])
        aug_input = T.AugInput(img)
        transforms = self.augmentations(aug_input)
        img = aug_input.image
        dataset_dict["image"] = torch.as_tensor(
            np.ascontiguousarray(img.transpose(2, 0, 1))
        )
        if not self.is_train:
            dataset_dict.pop("annotations", None)
            return dataset_dict
        annos = [
            utils.transform_instance_annotations(obj, transforms, img.shape[:2])
            for obj in dataset_dict.pop("annotations", [])
            if obj.get("iscrowd", 0) == 0
        ]
        dataset_dict["instances"] = utils.annotations_to_instances(
            annos, img.shape[:2]
        )
        return dataset_dict

class PlateTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        from detectron2.data import build_detection_train_loader
        return build_detection_train_loader(cfg, mapper=PNGMapper(is_train=True))

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        from detectron2.data import build_detection_test_loader
        return build_detection_test_loader(cfg, dataset_name, mapper=PNGMapper(is_train=False))

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "eval")
        return COCOEvaluator(dataset_name, output_dir=output_folder)

trainer = PlateTrainer(cfg)
trainer.resume_or_load(resume=True)

print(f"Starting training  |  {cfg.SOLVER.MAX_ITER} iterations  |  device=cpu  |  1 image/batch")
print(f"Checkpoints every {cfg.SOLVER.CHECKPOINT_PERIOD} iterations  |  output: {cfg.OUTPUT_DIR}")
print("-" * 60)

trainer.train()

print("-" * 60)
print(f"Training complete. Model saved to: {cfg.OUTPUT_DIR}")
# Out:
# [07/07 14:00:27 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
# ...

# %%
# NOTE: DeepDisc - cell 7
# Plots training losses from the metrics.json file detectron2 writes during training.
# Re-run this cell at any time after training starts to see the latest losses.

import json
import matplotlib.pyplot as plt
from pathlib import Path

metrics_path = Path(cfg.OUTPUT_DIR) / "metrics.json"

if not metrics_path.exists():
    print("No metrics.json found yet. Run cell 6 first.")
else:
    records = [json.loads(line) for line in metrics_path.read_text().splitlines() if line.strip()]

    iters       = [r["iteration"] for r in records if "total_loss" in r]
    total_loss  = [r["total_loss"] for r in records if "total_loss" in r]
    loss_cls    = [r.get("loss_cls", None) for r in records if "total_loss" in r]
    loss_box    = [r.get("loss_box_reg", None) for r in records if "total_loss" in r]
    loss_rpn_cls = [r.get("loss_rpn_cls", None) for r in records if "total_loss" in r]
    loss_rpn_box = [r.get("loss_rpn_loc", None) for r in records if "total_loss" in r]

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    axes[0].plot(iters, total_loss, color="white", linewidth=1.5, label="total_loss")
    axes[0].set_title("Total Loss", color="white")
    axes[0].set_xlabel("Iteration", color="white")
    axes[0].set_ylabel("Loss", color="white")
    axes[0].tick_params(colors="white")
    axes[0].legend(facecolor="#222", labelcolor="white")
    axes[0].set_facecolor("#111")
    for spine in axes[0].spines.values():
        spine.set_edgecolor("#444")

    for vals, label, color in [
        (loss_cls,     "loss_cls",     "cyan"),
        (loss_box,     "loss_box_reg", "orange"),
        (loss_rpn_cls, "loss_rpn_cls", "magenta"),
        (loss_rpn_box, "loss_rpn_loc", "yellow"),
    ]:
        if any(v is not None for v in vals):
            axes[1].plot(iters, vals, color=color, linewidth=1.2, label=label)

    axes[1].set_title("Loss Components", color="white")
    axes[1].set_xlabel("Iteration", color="white")
    axes[1].set_ylabel("Loss", color="white")
    axes[1].tick_params(colors="white")
    axes[1].legend(facecolor="#222", labelcolor="white")
    axes[1].set_facecolor("#111")
    for spine in axes[1].spines.values():
        spine.set_edgecolor("#444")

    fig.patch.set_facecolor("#1a1a1a")
    plt.suptitle(f"Training losses : {len(iters)} iterations logged", color="white", fontsize=11)
    plt.tight_layout()
    plt.show()

    print(f"Final total_loss: {total_loss[-1]:.4f}  (iteration {iters[-1]})")
# Out:
# Final total_loss: 1.1120  (iteration 1999)
